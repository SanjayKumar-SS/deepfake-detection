# %%
import tensorflow as tf

# %%
import os
from tensorflow.keras.preprocessing import image 
import numpy as np

# %%
# Program To Read video 
# and Extract Frames 

import os
import cv2 

# Function to extract frames 
def FrameCapture(path): 

    # Path to video file 
    vidObj = cv2.VideoCapture(path) 

    # Used as counter variable 
    count = 0

    # checks whether frames were extracted 
    success = 1

    # Create frames directory if it doesn't exist
    if not os.path.exists("frames"):
        os.makedirs("frames")

    while success: 

        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 

        # Check if the image is empty
        if not success:
            break

        # Saves the frames with frame-count 
        # Modifying to save frames with 'frame' prefix and count as multiples of 10
        frames_num = 20
        if count % frames_num == 0:
            cv2.imwrite("frames/frame%d.jpg" % (count), image) 

        count += 1



FrameCapture("/Users/pranaymishra/Desktop/deepfake/Dictators - Vladimir Putin.mp4")

# %%
loaded_model = tf.keras.models.load_model('deepfake_detection_model.h5')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 loaded_model = tf.keras.models.load_model('deepfake_detection_model.h5')
#
# File c:\Users\shafe\Documents\Shafeeq\deepfaker_deepfake_detector\venv\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File c:\Users\shafe\Documents\Shafeeq\deepfaker_deepfake_detector\venv\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:116, in load_model_from_hdf5(filepath, custom_objects, compile)
#     114 opened_new_file = not isinstance(filepath, h5py.File)
#     115 if opened_new_file:
# --> 116     f = h5py.File(filepath, mode="r")
#     117 else:
#     118     f = filepath
#
# File c:\Users\shafe\Documents\Shafeeq\deepfaker_deepfake_detector\venv\Lib\site-packages\h5py\_hl\files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File c:\Users\shafe\Documents\Shafeeq\deepfaker_deepfake_detector\venv\Lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'deepfake_detection_model.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
def evaluate_frames(directory):
    total_confidence = 0
    num_frames = 0

    # Iterate through frames in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".jpg"):
            img_path = os.path.join(directory, filename)
            img = image.load_img(img_path, target_size=(224, 224))
            img_array = image.img_to_array(img)
            img_array = np.expand_dims(img_array, axis=0)
            img_array /= 255.0  # Normalize pixel values

            # Predict
            confidence = loaded_model.predict(img_array)[0][0]
            total_confidence += confidence
            num_frames += 1

            # Print result
            if confidence >= 0.5:
                print(f"{filename}: Fake (Confidence: {confidence})")
            else:
                print(f"{filename}: Real (Confidence: {confidence})")

    # Calculate average confidence
    if num_frames > 0:
        average_confidence = total_confidence / num_frames
        print(f"Average Confidence: {average_confidence}")
        if average_confidence >= 0.5:
            print("The video is predicted as a deepfake.")
        else:
            print("The video is predicted as real.")
    else:
        print("No frames found in the directory.")


# Call the function to evaluate frames in the 'frames' directory
evaluate_frames("frames")
# Out:
# 1/1 [==============================] - 2s 2s/step
# frame540.jpg: Fake (Confidence: 0.593668520450592)
# 1/1 [==============================] - 0s 116ms/step
# frame420.jpg: Fake (Confidence: 0.612930417060852)
# 1/1 [==============================] - 0s 122ms/step
# frame780.jpg: Real (Confidence: 0.4413667321205139)
# 1/1 [==============================] - 0s 115ms/step
# frame580.jpg: Fake (Confidence: 0.5973744988441467)
# 1/1 [==============================] - 0s 112ms/step
# frame620.jpg: Real (Confidence: 0.43562543392181396)
# 1/1 [==============================] - 0s 112ms/step
# frame740.jpg: Real (Confidence: 0.4413853883743286)
# 1/1 [==============================] - 0s 117ms/step
# frame220.jpg: Fake (Confidence: 0.613996684551239)
# 1/1 [==============================] - 0s 108ms/step
# frame40.jpg: Fake (Confidence: 0.6271325945854187)
# 1/1 [==============================] - 0s 122ms/step
# frame340.jpg: Fake (Confidence: 0.5990725159645081)
# 1/1 [==============================] - 0s 116ms/step
# frame180.jpg: Fake (Confidence: 0.6028731465339661)
# 1/1 [==============================] - 0s 116ms/step
# frame80.jpg: Fake (Confidence: 0.6228286623954773)
# 1/1 [==============================] - 0s 157ms/step
# frame380.jpg: Fake (Confidence: 0.5894466638565063)
# 1/1 [==============================] - 0s 121ms/step
# frame140.jpg: Fake (Confidence: 0.5860578417778015)
# 1/1 [==============================] - 0s 116ms/step
# frame480.jpg: Fake (Confidence: 0.6141152381896973)
# 1/1 [==============================] - 0s 116ms/step
